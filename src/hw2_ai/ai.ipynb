# 38      1.0  27410005       2251840000000               双层蛋卷   NaN
# 41      2.0  27000582       2253215000000               盒饭系列   NaN
# 42     12.0  27000581       2253213000000               炒菜系列   NaN
# 43     13.0  27000581       2253213000000               炒菜系列   NaN
# 44      3.0  27200938  215322401000000019               面点系列   NaN
# 47      8.0  27400855  211211400800000011                菜煎饼   NaN
# 48     10.0  27400855  211211400800000011                菜煎饼   NaN
# 49      2.0  27400855  211211400800000011                菜煎饼   NaN
# ...     ...       ...                 ...                ...   ...
# 10833   1.0  27400126  213036900870000645              现烤鱿鱼头   NaN
# 10835   1.0  27410000  215041400600000069              八分场凉皮   NaN
# 10836   1.0  27200924  215043000800000012                 热面   NaN
# 10838   1.0  27000582       2253215000000               盒饭系列   NaN
# 10839   1.0  27000582       2253215000000               盒饭系列   NaN
# 10840   1.0  27000582       2253215000000               盒饭系列   NaN
# 10841   1.0  23132068  202976301094005585              干点系列1     1
# 10842   1.0  23132068  202976300839004289              干点系列1     1
# 10843   1.0  27002194  210622800445002046          喜旺精肉肠（蒜香）   NaN
# 10848   4.0  25111048       2010047000000               白菜肉包     1
# 10849   5.0  25111048       2010047000000               白菜肉包     1
# 10850   1.0  25111048       2010047000000               白菜肉包     1
# 10851   2.0  25111048       2010047000000               白菜肉包     1
# 10852   1.0  27002169  210617808844006922            喜旺老汤牛腱肉   NaN
# 10853   2.0  25101044       2250013000000                甜味饼   NaN
# 10854   3.0  25101044       2250013000000                甜味饼   NaN
# 10855   5.0  27000582       2253215000000               盒饭系列   NaN
# 10856   3.0  27000581       2253213000000               炒菜系列   NaN
# 10857   4.0  27000581       2253213000000               炒菜系列   NaN
# 10858   1.0  22030005  200422102683014922              玫瑰香葡萄     1
# 10859   2.0  27410000  215041400600000069              八分场凉皮   NaN
# 10860   1.0  27410000  215041400600000069              八分场凉皮   NaN
# 10861   2.0  27410000  215041400600000069              八分场凉皮   NaN
# 10866   2.0  11230065       6903148045183  海飞丝水润滋养型去屑洗发露200m  1*24
# 10867   3.0  27000576  215042600700000078                麻辣烫   NaN
# 10868   1.0  27200924  215043000800000012                 热面   NaN
# 10869   2.0  27200924  215043000800000012                 热面   NaN
# 10870   3.0  27200924  215043000800000012                 热面   NaN
# 10871   1.0  27200924  215043000800000012                 热面   NaN
# 10872   4.0  27410005       2251840000000               双层蛋卷   NaN
#
#            ...       dptno  dptname bndno  bndname      qty    amt  disamt  \
# 0          ...       27400     特色熟食   NaN      NaN    0.001   8.00     0.0
# 1          ...       27400     特色熟食   NaN      NaN    0.001   8.00     0.0
# 2          ...       27400     特色熟食   NaN      NaN    0.001   8.00     0.0
# 3          ...       22000     本地苹果   NaN      NaN    0.812   9.73     0.0
# 4          ...       22000     本地苹果   NaN      NaN    1.176  11.74     0.0
# 5          ...       22000     本地苹果   NaN      NaN    1.136  13.61     0.0
# 7          ...       27300     豆制品类   NaN      NaN    4.000   2.00     0.0
# 8          ...       27300     豆制品类   NaN      NaN    5.000   2.50     0.0
# 9          ...       25120     普通馒头   NaN      NaN    4.000   2.80     0.0
# 14         ...       22103      结球类   NaN      NaN    0.548   2.72     0.0
# 15         ...       23110      甜面包   NaN      NaN   22.000  22.00     0.0
# 16         ...       22102      瓜果类   NaN      NaN    0.948   1.88     0.0
# 17         ...       22102      瓜果类   NaN      NaN    0.546   2.60     0.0
# 20         ...       22102      瓜果类   NaN      NaN    0.524   1.76     0.0
# 29         ...       11250      花露水   NaN      NaN    1.000  16.80     0.0
# 30         ...       27000    熟食凉拌类   NaN      NaN    0.738  12.99     0.0
# 31         ...       27200     面点类1   NaN      NaN    0.006   6.00     0.0
# 33         ...       27410     地方小吃   NaN      NaN    1.333   8.00     0.0
# 34         ...       27410     地方小吃   NaN      NaN    1.333   8.00     0.0
# 35         ...       27410     地方小吃   NaN      NaN    1.000   5.00     0.0
# 36         ...       27410     地方小吃   NaN      NaN    1.000   5.00     0.0
# 37         ...       27410     地方小吃   NaN      NaN    1.000   5.00     0.0
# 38         ...       27410     地方小吃   NaN      NaN    1.000   5.00     0.0
# 41         ...       27000    熟食凉拌类   NaN      NaN    1.000   8.00     0.0
# 42         ...       27000    熟食凉拌类   NaN      NaN  254.000   5.49     0.0
# 43         ...       27000    熟食凉拌类   NaN      NaN  144.000   3.97     0.0
# 44         ...       27200     面点类1   NaN      NaN    0.001  10.00     0.0
# 47         ...       27400     特色熟食   NaN      NaN    0.001   8.00     0.0
# 48         ...       27400     特色熟食   NaN      NaN    0.001   8.00     0.0
# 49         ...       27400     特色熟食   NaN      NaN    0.001   8.00     0.0
# ...        ...         ...      ...   ...      ...      ...    ...     ...
# 10833      ...       27400     特色熟食   NaN      NaN    0.064   8.70     0.0
# 10835      ...       27410     地方小吃   NaN      NaN    0.006   6.00     0.0
# 10836      ...       27200     面点类1   NaN      NaN    0.001   8.00     0.0
# 10838      ...       27000    熟食凉拌类   NaN      NaN    1.250  10.00     0.0
# 10839      ...       27000    熟食凉拌类   NaN      NaN    0.438   3.50     0.0
# 10840      ...       27000    熟食凉拌类   NaN      NaN    1.250  10.00     0.0
# 10841      ...       23132      酥皮类   NaN      NaN    0.558  10.94     0.0
# 10842      ...       23132      酥皮类   NaN      NaN    0.428   8.39     0.0
# 10843      ...       27002      熟肉类   NaN      NaN    0.204   4.45     0.0
# 10848      ...       25111      肉馅类   NaN      NaN    4.000   8.00     0.0
# 10849      ...       25111      肉馅类   NaN      NaN    2.000   4.00     0.0
# 10850      ...       25111      肉馅类   NaN      NaN    3.000   6.00     0.0
# 10851      ...       25111      肉馅类   NaN      NaN    5.000  10.00     0.0
# 10852      ...       27002      熟肉类   NaN      NaN    0.692  88.44     0.0
# 10853      ...       25101      多味饼   NaN      NaN    3.000   6.00     0.0
# 10854      ...       25101      多味饼   NaN      NaN    3.000   6.00     0.0
# 10855      ...       27000    熟食凉拌类   NaN      NaN    1.000   8.00     0.0
# 10856      ...       27000    熟食凉拌类   NaN      NaN  570.000  27.13     0.0
# 10857      ...       27000    熟食凉拌类   NaN      NaN  646.000  30.75     0.0
# 10858      ...       22030       葡萄   NaN      NaN    1.492  26.83     0.0
# 10859      ...       27410     地方小吃   NaN      NaN    0.006   6.00     0.0
# 10860      ...       27410     地方小吃   NaN      NaN    0.006   6.00     0.0
# 10861      ...       27410     地方小吃   NaN      NaN    0.006   6.00     0.0
# 10866      ...       11230    一般洗发水   NaN      NaN    1.000  27.20     0.0
# 10867      ...       27000    熟食凉拌类   NaN      NaN    0.007   7.00     0.0
# 10868      ...       27200     面点类1   NaN      NaN    0.001   8.00     0.0
# 10869      ...       27200     面点类1   NaN      NaN    0.001   8.00     0.0
# 10870      ...       27200     面点类1   NaN      NaN    0.001   8.00     0.0
# 10871      ...       27200     面点类1   NaN      NaN    0.001   8.00     0.0
# 10872      ...       27410     地方小吃   NaN      NaN    1.000   5.00     0.0
#
#        ismmx  mtype        mdocno
# 0          0    NaN           NaN
# 1          0    NaN           NaN
# 2          0    NaN           NaN
# 3          0    NaN           NaN
# 4          0    NaN           NaN
# 5          0    NaN           NaN
# 7          0    NaN           NaN
# 8          0    NaN           NaN
# 9          0    NaN           NaN
# 14         0    NaN           NaN
# 15         0    NaN           NaN
# 16         0    NaN           NaN
# 17         0    NaN           NaN
# 20         0    NaN           NaN
# 29         1   快讯促销  5.262662e+14
# 30         0    NaN           NaN
# 31         0    NaN           NaN
# 33         0    NaN           NaN
# 34         0    NaN           NaN
# 35         0    NaN           NaN
# 36         0    NaN           NaN
# 37         0    NaN           NaN
# 38         0    NaN           NaN
# 41         0    NaN           NaN
# 42         0    NaN           NaN
# 43         0    NaN           NaN
# 44         0    NaN           NaN
# 47         0    NaN           NaN
# 48         0    NaN           NaN
# 49         0    NaN           NaN
# ...      ...    ...           ...
# 10833      0    NaN           NaN
# 10835      0    NaN           NaN
# 10836      0    NaN           NaN
# 10838      0    NaN           NaN
# 10839      0    NaN           NaN
# 10840      0    NaN           NaN
# 10841      0    NaN           NaN
# 10842      0    NaN           NaN
# 10843      0    NaN           NaN
# 10848      0    NaN           NaN
# 10849      0    NaN           NaN
# 10850      0    NaN           NaN
# 10851      0    NaN           NaN
# 10852      0    NaN           NaN
# 10853      0    NaN           NaN
# 10854      0    NaN           NaN
# 10855      0    NaN           NaN
# 10856      0    NaN           NaN
# 10857      0    NaN           NaN
# 10858      0    NaN           NaN
# 10859      0    NaN           NaN
# 10860      0    NaN           NaN
# 10861      0    NaN           NaN
# 10866      0    NaN           NaN
# 10867      0    NaN           NaN
# 10868      0    NaN           NaN
# 10869      0    NaN           NaN
# 10870      0    NaN           NaN
# 10871      0    NaN           NaN
# 10872      0    NaN           NaN
#
# [5585 rows x 21 columns]

# %%
# use a dict to store the transaction of each vip
# also record the sldatime
l_data = len(raw_data)
vip_transaction = {}
vip_set = set()
for i in range(l_data):
    v = raw_data.loc[i, 'vipno']
    t = raw_data.loc[i, 'sldat'] # sldat -> trade.csv   sldatime -> trade_new.csv
    if v in vip_set:
        vip_transaction[v].append((t, i))
    else:
        vip_transaction[v] = [(t, i)]
        vip_set.add(v)

# %%
# sort and cut the data
vip_list = list(vip_set)
for v in vip_list:
    # sort
    t = vip_transaction[v]
    t = sorted(t, key=lambda x:x[0])
    
    # cut and pick up the index only
    l = round(len(t) * 0.6)
    t = t[:l]
    vip_transaction[v] = [tt[1] for tt in t] # tt[0] --> time , tt[1] --> index of raw_data

# %%
def split_transaction(indice, item_label, transactions):
    split_data = raw_data.loc[indice, ['uid', item_label]] # get the uid and pluno/dptno/bndno columns
    if item_label == 'bndno':
        split_data = split_data.dropna(how='any')
        split_data['bndno'] = split_data['bndno'].astype('int')
    groups = split_data.groupby('uid').groups
    for u in groups:
        index = groups[u] # index of the same uid
        t = list(split_data.loc[index, item_label]) # get one transaction
        transactions.append(t)

# %%
item_labels = ['dptno', 'pluno', 'bndno']
time_duration = []
for item_label in item_labels:
    print("item -- {}".format(item_label))
    # fill the transactions with the items
    transactions = []
    for v in vip_list:
        split_transaction(vip_transaction[v], item_label, transactions)
    print(len(transactions)) # print the transaction number
    # call FP algorithm
    supports = [64, 32, 16, 8, 4, 2]
    for s in supports:
        time_start=time.time()
        patterns = pyfpgrowth.find_frequent_patterns(transactions, s)
        with open('fp_{0}_{1}.txt'.format(item_label, s), 'w') as f:
            for p in patterns:
                f.write(str(list(p))+'\n')
        time_end=time.time()
        print('support = {} done. totally cost = '.format(s), timedelta(seconds=time_end-time_start))
        time_duration.append(time_end-time_start)
# Out:
# item -- dptno
# 1585
# support = 64 done. totally cost =  0:00:00.023316
# support = 32 done. totally cost =  0:00:00.051754
# support = 16 done. totally cost =  0:00:00.084985
# support = 8 done. totally cost =  0:00:00.481444
# support = 4 done. totally cost =  0:00:01.817188
# support = 2 done. totally cost =  0:00:37.756611
# item -- pluno
# 1585
# support = 64 done. totally cost =  0:00:00.228527
# support = 32 done. totally cost =  0:00:00.018167
# support = 16 done. totally cost =  0:00:00.028643
# support = 8 done. totally cost =  0:00:00.041621
# support = 4 done. totally cost =  0:00:00.122196
# support = 2 done. totally cost =  0:00:01.484981
# item -- bndno
# 1030
# support = 64 done. totally cost =  0:00:00.026550
# support = 32 done. totally cost =  0:00:00.016453
# support = 16 done. totally cost =  0:00:00.031630
# support = 8 done. totally cost =  0:00:00.295592
# support = 4 done. totally cost =  0:00:02.266494
# support = 2 done. totally cost =  0:00:44.671863

# %%
print(time_duration[:6])
print(time_duration[6:12])
print(time_duration[12:])
# Out:
# [0.023315906524658203, 0.051753997802734375, 0.08498501777648926, 0.4814441204071045, 1.817187786102295, 37.75661110877991]
# [0.22852706909179688, 0.01816701889038086, 0.028643131256103516, 0.04162096977233887, 0.12219595909118652, 1.484980821609497]
# [0.0265500545501709, 0.016453027725219727, 0.03163003921508789, 0.2955920696258545, 2.266494035720825, 44.671863079071045]

# %%
item_labels = ['dptno', 'pluno', 'bndno']
numbers = []
for item_label in item_labels:
    supports = [64, 32, 16, 8, 4, 2]
    for s in supports:
        item_number = 0 
        with open('new_results/fp_{0}_{1}.txt'.format(item_label, s), 'r') as f:
            for line in f:
                item_number += 1
        print(item_number)
        numbers.append(item_number)
# Out:
# 77
# 213
# 864
# 5118
# 166152
# 18321374
# 11
# 56
# 156
# 563
# 25479
# 52527095
# 23
# 85
# 497
# 3308
# 17044
# 199913

# %%
with open('number.csv', 'w') as f:
    t = ','.join([str(x) for x in numbers[:6]])
    f.write(t + '\n')
    t = ','.join([str(x) for x in numbers[6:12]])
    f.write(t + '\n')
    t = ','.join([str(x) for x in numbers[12:]])
    f.write(t + '\n')
